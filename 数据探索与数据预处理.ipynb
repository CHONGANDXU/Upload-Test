# %% [markdown]
# ## 实验一：对Breast Cancer数据集进行数据探索与数据预处理操作
#
# 从以下网址下载数据集
# http://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Coimbra

# %% [markdown]
# ### 一、了解数据

# %% [markdown]
# 1.打开下载的数据集文件，查看数据的前5行

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("dataR2.csv")
df.head()
# Out:
#    Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409   8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897   8.8438     5.429285   4.06405
# 2   82  23.124670       91    4.498  1.009651  17.9393    22.432040   9.27715
# 3   68  21.367521       77    3.226  0.612725   9.8827     7.169560  12.76600
# 4   86  21.111111       92    3.549  0.805386   6.6994     4.819240  10.57635
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1
# 2  554.697               1
# 3  928.220               1
# 4  773.920               1

# %% [markdown]
# 2.显示数据的列名、索引情况

# %%
print(df.index,'\n')
print(df.columns)
# Out:
# RangeIndex(start=0, stop=116, step=1)
#
# Index(['Age', 'BMI', 'Glucose', 'Insulin', 'HOMA', 'Leptin', 'Adiponectin',
#        'Resistin', 'MCP.1', 'Classification'],
#       dtype='object')

# %% [markdown]
# 3.显示数据的形状、基本信息、类型

# %%
df.shape
# Out:
# (116, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             116 non-null    int64
#  1   BMI             116 non-null    float64
#  2   Glucose         116 non-null    int64
#  3   Insulin         116 non-null    float64
#  4   HOMA            116 non-null    float64
#  5   Leptin          116 non-null    float64
#  6   Adiponectin     116 non-null    float64
#  7   Resistin        116 non-null    float64
#  8   MCP.1           116 non-null    float64
#  9   Classification  116 non-null    int64
# dtypes: float64(7), int64(3)
# memory usage: 9.2 KB

# %% [markdown]
# 4.调用describe()函数进一步查看数据特征整体情况

# %%
df.describe()
# Out:
#               Age         BMI     Glucose     Insulin        HOMA      Leptin  \
# count  116.000000  116.000000  116.000000  116.000000  116.000000  116.000000
# mean    57.301724   27.582111   97.793103   10.012086    2.694988   26.615080
# std     16.112766    5.020136   22.525162   10.067768    3.642043   19.183294
# min     24.000000   18.370000   60.000000    2.432000    0.467409    4.311000
# 25%     45.000000   22.973205   85.750000    4.359250    0.917966   12.313675
# 50%     56.000000   27.662416   92.000000    5.924500    1.380939   20.271000
# 75%     71.000000   31.241442  102.000000   11.189250    2.857787   37.378300
# max     89.000000   38.578759  201.000000   58.460000   25.050342   90.280000
#
#        Adiponectin    Resistin        MCP.1  Classification
# count   116.000000  116.000000   116.000000      116.000000
# mean     10.180874   14.725966   534.647000        1.551724
# std       6.843341   12.390646   345.912663        0.499475
# min       1.656020    3.210000    45.843000        1.000000
# 25%       5.474283    6.881763   269.978250        1.000000
# 50%       8.352692   10.827740   471.322500        2.000000
# 75%      11.815970   17.755207   700.085000        2.000000
# max      38.040000   82.100000  1698.440000        2.000000

# %% [markdown]
# 6.对数据集的含义及情况做大致描述（采用文字）

# %% [markdown]
# 数据集的维度为 116 * 10 的矩阵，共有10个属性（列）和116组数据（行），有 10 个预测变量，都是定量的和一个二元因变量

# %% [markdown]
# 7.患病数据和健康数据分别是多少

# %%
print('患病数据有：','\n',df[df.iloc[:,9]==2].iloc[:,9].count())
print()
print('健康数据有：','\n',df[df.iloc[:,9]==1].iloc[:,9].count())
# Out:
# 患病数据有：
#  64
#
# 健康数据有：
#  52

# %% [markdown]
# 8.年龄在25-50之间的数据

# %%
df[(df.iloc[:,0]>=25) & (df.iloc[:,0]<=50)]
# Out:
#      Age        BMI  Glucose  Insulin       HOMA   Leptin  Adiponectin  \
# 0     48  23.500000       70    2.707   0.467409   8.8071     9.702400
# 5     49  22.854458       92    3.226   0.732087   6.8317    13.679750
# 10    34  21.470000       78    3.469   0.667436  14.5700    13.110000
# 11    29  23.010000       82    5.663   1.145436  35.5900    26.720000
# 12    25  22.860000       82    4.090   0.827271  20.4500    23.670000
# 14    38  23.340000       75    5.782   1.069670  15.2600    17.950000
# 15    44  20.760000       86    7.553   1.600000  14.0900    20.320000
# 16    47  22.030000       84    2.869   0.590000  26.6500    38.040000
# 19    32  36.512637       87   14.026   3.009980  49.3727     5.100000
# 20    36  28.576676       86    4.345   0.921719  15.1248     8.600000
# 21    34  31.975015       87    4.530   0.972138  28.7502     7.642760
# 22    29  32.270788       84    5.810   1.203832  45.6196     6.209635
# 23    35  30.276817       84    4.376   0.906707  39.2134     9.048185
# 25    45  37.035608       83    6.760   1.383997  39.9802     4.617125
# 26    50  38.578759      106    6.703   1.752611  46.6401     4.667645
# 28    35  35.250761       90    6.817   1.513374  50.6094     6.966895
# 29    36  34.174890       80    6.590   1.300427  10.2809     5.065915
# 32    28  35.855815       87    8.576   1.840410  68.5102     4.794200
# 33    43  34.422174       89   23.194   5.091856  31.2128     8.300955
# 52    45  21.303949      102   13.852   3.485163   7.6476    21.056625
# 53    45  20.829995       74    4.560   0.832352   7.7529     8.237405
# 54    49  20.956608       94   12.305   2.853119  11.2406     8.412175
# 55    34  24.242424       92   21.699   4.924226  16.7353    21.823745
# 56    42  21.359915       93    2.999   0.687971  19.0826     8.462915
# 60    38  22.499637       95    5.261   1.232828   8.4380     4.771920
# 62    49  21.367521       78    2.640   0.507936   6.3339     3.886145
# 65    45  23.140496      116    4.902   1.402626  17.9973     4.294705
# 68    46  20.830000       88    3.420   0.742368  12.8700    18.550000
# 69    44  19.560000      114   15.890   4.468268  13.0800    20.370000
# 70    45  20.260000       92    3.440   0.780651   7.6500    16.670000
# 71    44  24.740000      106   58.460  15.285341  18.1600    16.100000
# 74    46  22.210000       86   36.940   7.836205  10.1600     9.760000
# 75    43  26.562500      101   10.555   2.629602   9.8000     6.420295
# 77    43  31.250000      103    4.328   1.099601  25.7816    12.718960
# 79    41  26.672763       97   22.033   5.271762  44.7059    13.494865
# 82    48  32.461911       99   28.677   7.002923  46.0760    21.570000
# 84    42  29.296875       98    4.172   1.008511  12.2617     6.695585
# 86    48  28.125000       90    2.540   0.563880  15.5325    10.222310
# 88    48  31.250000      199   12.162   5.969920  18.1314     4.104105
# 90    40  30.836531      128   41.894  13.227332  31.0385     6.160995
# 93    49  32.461911      134   24.887   8.225983  42.3914    10.793940
# 95    49  29.777778       70    8.396   1.449709  51.3387    10.731740
# 96    44  27.887617       99    9.208   2.248594  12.6757     5.478170
# 97    40  27.636054      103    2.432   0.617890  14.3224     6.783870
# 106   45  29.384757       90    4.713   1.046286  23.8479     6.644245
# 107   46  33.180000       92    5.750   1.304867  18.6900     9.160000
# 111   45  26.850000       92    3.330   0.755688  54.6800    12.100000
#
#      Resistin     MCP.1  Classification
# 0     7.99585   417.114               1
# 5    10.31760   530.410               1
# 10    6.92000   354.600               1
# 11    4.58000   174.800               1
# 12    5.14000   313.730               1
# 14    9.35000   165.020               1
# 15    7.64000    63.610               1
# 16    3.32000   191.720               1
# 19   17.10223   588.460               1
# 20    9.15390   534.224               1
# 21    5.62592   572.783               1
# 22   24.60330   904.981               1
# 23   16.43706   733.797               1
# 25    8.70448   586.173               1
# 26   11.78388   887.160               1
# 28   22.03703   667.928               1
# 29   15.72187   581.313               1
# 32   21.44366   358.624               1
# 33    6.71026   960.246               1
# 52   23.03408   552.444               2
# 53   28.03230   382.955               2
# 54   23.11770   573.630               2
# 55   12.06534   481.949               2
# 56   17.37615   321.919               2
# 60   15.73606   199.055               2
# 62   22.94254   737.672               2
# 65    5.26330   518.586               2
# 68   13.56000   301.210               2
# 69    4.62000   220.660               2
# 70    7.84000   193.870               2
# 71    5.31000   244.750               2
# 74    5.68000   312.000               2
# 75   16.10000   806.724               2
# 77   38.65310   775.322               2
# 79   27.83250   783.796               2
# 82   10.15726   738.034               2
# 84   53.67170  1041.843               2
# 86   16.11032  1698.440               2
# 88   53.63080  1698.440               2
# 90   17.55503   638.261               2
# 93    5.76800   656.393               2
# 95   20.76801   602.486               2
# 96   23.03306   407.206               2
# 97   26.01360   293.123               2
# 106  15.55625   621.273               2
# 107   8.89000   209.190               2
# 111  10.96000   268.230               2

# %% [markdown]
# 9.显示特征是Age、BMI、MCP.1的第4-10数据

# %%
df.loc[3:9,['Age','BMI','MCP.1']]
# Out:
#    Age        BMI     MCP.1
# 3   68  21.367521   928.220
# 4   86  21.111111   773.920
# 5   49  22.854458   530.410
# 6   89  22.700000  1256.083
# 7   76  23.800000   280.694
# 8   73  22.000000   136.855
# 9   75  23.000000   318.302

# %% [markdown]
# ### 二、数据预处理

# %% [markdown]
# #### 1.缺失值处理
# 检查数据的缺失值情况，若有缺失值，统计各特征缺失值多少情况，并做出合理处理，如值替换等

# %%
df.isnull().sum()
# Out:
# Age               0
# BMI               0
# Glucose           0
# Insulin           0
# HOMA              0
# Leptin            0
# Adiponectin       0
# Resistin          0
# MCP.1             0
# Classification    0
# dtype: int64

# %% [markdown]
# #### 2.重复值检测，如有重复值，做删除处理

# %%
df.drop_duplicates(keep=False)
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0     48  23.500000       70    2.707  0.467409   8.8071     9.702400
# 1     83  20.690495       92    3.115  0.706897   8.8438     5.429285
# 2     82  23.124670       91    4.498  1.009651  17.9393    22.432040
# 3     68  21.367521       77    3.226  0.612725   9.8827     7.169560
# 4     86  21.111111       92    3.549  0.805386   6.6994     4.819240
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   45  26.850000       92    3.330  0.755688  54.6800    12.100000
# 112   62  26.840000      100    4.530  1.117400  12.4500    21.420000
# 113   65  32.050000       97    5.730  1.370998  61.4800    22.540000
# 114   72  25.590000       82    2.820  0.570392  24.9600    33.750000
# 115   86  27.180000      138   19.910  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1  Classification
# 0     7.99585  417.114               1
# 1     4.06405  468.786               1
# 2     9.27715  554.697               1
# 3    12.76600  928.220               1
# 4    10.57635  773.920               1
# ..        ...      ...             ...
# 111  10.96000  268.230               2
# 112   7.32000  330.160               2
# 113  10.33000  314.050               2
# 114   3.27000  392.460               2
# 115   4.35000   90.090               2
#
# [116 rows x 10 columns]

# %% [markdown]
# #### 3.利用箱型图对Glucose做异常值检测,说明有无异常值，如有异常值，异常值个数是多少，分别是？

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
df.loc[:,'Glucose'].plot.box()
plt.show()

df_Glucose=df.loc[:,'Glucose']
df_Glucose.head()

IQR=df_Glucose.quantile(0.75)-df_Glucose.quantile(0.25)
val_low=df_Glucose.quantile(0.25)-1.5*IQR
val_up=df_Glucose.quantile(0.75)+1.5*IQR
print('IQR:{}'.format(IQR))
print('Q_LOW:{}'.format(val_low))
print('Q_UP:{}'.format(val_up))

print()

print('异常值共有:{}'.format(df_Glucose[df_Glucose<=val_low].count()+df_Glucose[df_Glucose>=val_up].count()))
print()
print(df_Glucose[df_Glucose<=val_low])
print()
print(df_Glucose[df_Glucose>=val_up])
# Out:
# IQR:16.25
# Q_LOW:61.375
# Q_UP:126.375
#
# 异常值共有:12
#
# 47    60
# Name: Glucose, dtype: int64
#
# 78     201
# 87     196
# 88     199
# 89     139
# 90     128
# 93     134
# 94     131
# 105    134
# 108    131
# 109    152
# 115    138
# Name: Glucose, dtype: int64

# %% [markdown]
# #### 4.对检测的异常值进行过滤

# %%
df_change=df_Glucose[(df_Glucose>=val_low)&(df_Glucose<=val_up)]
df_change.describe()
# Out:
# count    104.000000
# mean      92.317308
# std       10.460526
# min       70.000000
# 25%       85.000000
# 50%       92.000000
# 75%      100.000000
# max      119.000000
# Name: Glucose, dtype: float64

# %% [markdown]
# #### 5.对MCP.1进行最小-最大规范化

# %%
#（1）自编最小-最大规范化函数。
df_MCP=df.loc[:,'MCP.1']
df_MCP.describe()
min=df_MCP.describe().iloc[3]
max=df_MCP.describe().iloc[7]
#print(min,max)
n=0
for i in df_MCP:
    df_MCP.iloc[n]=(i - min) / (max - min)
    n=n+1
print(df_MCP)
# Out:
# C:\Users\CqC33\AppData\Local\Temp\ipykernel_16256\561018846.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_MCP.iloc[n]=(i - min) / (max - min)
# 0      0.224659
# 1      0.255926
# 2      0.307912
# 3      0.533934
# 4      0.440565
#          ...
# 111    0.134568
# 112    0.172043
# 113    0.162294
# 114    0.209741
# 115    0.026774
# Name: MCP.1, Length: 116, dtype: float64

# %% [markdown]
# #### 6.相关性，所有特征之间的相关性情况

# %%
# 欧式距离（Eulidean distance）
def euclidean(x, y):
    return np.sqrt(np.sum((x-y)**2))

# 曼哈顿距离(Manhattan distance)
def manhattan(x,y):
    return np.sum(np.abs(x-y))

#切比雪夫距离(Chebyshev distance)
def chebyshev(x,y):
    return np.max(np.abs(x-y))

# 闵可夫斯基距离(Minkowski distance)
def minkowski(x,y,p):
    return np.sum(np.abs(x-y)**p)**(1/p)

# 汉明距离(Hamming distance)
def hamming(x, y):
    return np.sum(x!=y)/len(x)

# 余弦距离
def cos_similarity(x, y):
    return np.dot(x,y)/(np.linalg.norm(x)*np.linalg.norm(y))

from scipy.spatial.distance import pdist
x=df.iloc[:,0]
y=df.iloc[:,1]
X=np.vstack([x,y])  #按垂直方向（行顺序）堆叠数组构成一个新的数组，堆叠的数组需要具有相同的维度

print('Age与BMI的距离为：')
d1= pdist(X, 'euclidean')
print('欧式距离：',d1)

d2=pdist(X,'cityblock')
print('曼哈顿距离：',d2)

d3=pdist(X,'chebyshev')
print('切比雪夫距离：',d3)

d4=pdist(X,'minkowski',p=2)
print('闵可夫斯基距离：',d4)

d5=pdist(X,'cosine')
print('余弦相似性：',1-d5)
# Out:
# Age与BMI的距离为：
# 欧式距离： [367.49636536]
# 曼哈顿距离： [3479.25514594]
# 切比雪夫距离： [66.3]
# 闵可夫斯基距离： [367.49636536]
# 余弦相似性： [0.94794654]

# %%
# 通过热力图可视化数据相关性
from string import ascii_letters
import seaborn as sns

sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 7.离散化。
# 等距离散化
# 使用Pandas中的cut方法，对BMI实现等距离散化分组，根据中国标准BMI值: 正常:18.5-23.9、超重:≥24、偏胖:24～27.9、肥胖:≥28划分

# %%
BMI_groups1=pd.cut(df['BMI'],bins=[0,18.5,23.9,27.9,100],labels=['偏瘦','正常','偏胖','肥胖'])
#print(BMI_groups1)
print(df['Classification'].groupby(BMI_groups1).count())
# Out:
# BMI
# 偏瘦     1
# 正常    36
# 偏胖    25
# 肥胖    54
# Name: Classification, dtype: int64

# %% [markdown]
# #### 8.等频离散化，每箱的数据个数约为总数的四分之一

# %%
BMI_groups2=pd.qcut(df['BMI'],4)
BMI_groups2
# Out:
# 0      (22.973, 27.662]
# 1      (18.369, 22.973]
# 2      (22.973, 27.662]
# 3      (18.369, 22.973]
# 4      (18.369, 22.973]
#              ...
# 111    (22.973, 27.662]
# 112    (22.973, 27.662]
# 113    (31.241, 38.579]
# 114    (22.973, 27.662]
# 115    (22.973, 27.662]
# Name: BMI, Length: 116, dtype: category
# Categories (4, interval[float64, right]): [(18.369, 22.973] < (22.973, 27.662] < (27.662, 31.241] < (31.241, 38.579]]

# %% [markdown]
# ### 三.数据可视化
# 1. 绘制年龄分布直方图，bins=4。
# 2. bar的宽度为0.8,直方为蓝色。
# 3. 观察绘制的直方图，简要说明年龄分布情况。

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']

df_Age=df.loc[:,'Age']
m1=np.array(df_Age)
fre_tuple1 = plt.hist(m1, bins=4, rwidth=0.8,edgecolor='steelblue', color='blue')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age直方图')
x_loc = fre_tuple1[0] 
y_loc = fre_tuple1[1]
#print(x_loc,'\n',y_loc)
for x,y in zip(x_loc,y_loc): 
    plt.text(y+8, x+0.1, '%.0f' % x, ha='center', va= 'bottom',fontsize=13)

# %% [markdown]
# 2.绘制BMI分布直方图，bins=[18,24,27,40],直方为绿色

# %%
df_BMI=df.loc[:,'BMI']
m2=np.array(df_BMI)
fre_tuple2 = plt.hist(m2, bins=[18,24,27,40],edgecolor='steelblue', color='green')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.title('BMI直方图')
x_loc = fre_tuple2[0] 
y_loc = fre_tuple2[1]
#print(x_loc,'\n',y_loc)
for x,y in zip(x_loc,y_loc): 
    plt.text(y+2, x+0.1, '%.0f' % x, ha='center', va= 'bottom',fontsize=13)

# %% [markdown]
# 3.调用sns.countplot()函数，探索患病情况与年龄的关系。

# %%
df['age_range']=pd.cut(df['Age'],bins=[0,18,40,66,200],labels=['儿童','青年','中年','老年'])
ax=sns.countplot(x=df['age_range'],hue=df['Classification'])
ax.set_xlabel('年龄段')
ax.set_ylabel('数量')
# Out:
# Text(0, 0.5, '数量')

# %% [markdown]
# ### 四、数据降维

# %%
import numpy as np
from sklearn.decomposition import PCA

X = np.array(df.iloc[:,0:9],type(float))
pca = PCA(n_components=0.9)
newX = pca.fit_transform(X)

print(X,'\n')

print(newX,'\n')

print(pca.explained_variance_ratio_)
# Out:
# [[48.0 23.5 70.0 ... 9.7024 7.99585 0.22465912742186991]
#  [83.0 20.69049454 92.0 ... 5.429285 4.06405 0.2559262784574824]
#  [82.0 23.12467037 91.0 ... 22.43204 9.27715 0.3079117292358633]
#  ...
#  [65.0 32.05 97.0 ... 22.54 10.33 0.16229425564732358]
#  [72.0 25.59 82.0 ... 33.75 3.27 0.20974078979932795]
#  [86.0 27.18 138.0 ... 14.11 4.35 0.026774222632620054]]
#
# [[-3.57925367e+01 -7.44835777e-01  2.12692071e+00  3.67380709e-01]
#  [-1.17384302e+01 -2.12690900e+01 -2.49164316e+01 -2.22070710e+00]
#  [-7.77691986e+00 -1.20650436e+01 -2.35614918e+01 -2.37409827e+00]
#  [-2.45675290e+01 -8.46499813e+00 -1.40283600e+01  5.91841360e+00]
#  [-1.07001627e+01 -2.31853414e+01 -2.64165291e+01  4.52141608e+00]
#  [-1.87223421e+01 -1.24143472e+01  8.26309708e+00 -5.64506617e-01]
#  [-2.10604591e+01 -1.66093697e+01 -3.27752533e+01  8.36816589e+00]
#  [ 6.18298600e+00 -3.42519342e+01 -9.36107651e+00 -6.36874979e+00]
#  [-1.15674541e+01 -2.39077008e+01 -1.28609445e+01 -1.91263101e+00]
#  [-1.57335949e+01 -7.47467889e+00 -2.02805801e+01 -1.83684302e+00]
#  [-2.99369583e+01  3.96737464e+00  1.64798375e+01 -4.52285641e+00]
#  [-1.83599747e+01  2.10086335e+01  1.96270285e+01 -1.40153985e+01]
#  [-2.64703042e+01  9.62938916e+00  2.55398120e+01 -1.05659733e+01]
#  [-2.74543953e+01 -2.78373763e+00  3.17610696e+01 -1.09160931e+01]
#  [-3.02526444e+01  5.25955998e+00  1.29048571e+01 -3.04499850e+00]
#  [-2.10207463e+01 -2.91077843e+00  1.08555803e+01 -6.11578890e+00]
#  [-1.88502534e+01  7.49121651e+00  5.52636168e+00 -1.43093884e+01]
#  [-5.28597673e+00  8.53974214e+00 -6.84058580e+00 -7.47179123e-01]
#  [-5.66403661e+00 -4.82284928e+00 -8.45893226e+00 -3.64842057e+00]
#  [-7.73340584e-01  3.22457742e+01  1.67153539e+01 -1.72684252e+00]
#  [-2.15582105e+01  1.46015979e+00  1.66391822e+01 -2.42109790e+00]
#  [-1.51025501e+01  1.29872248e+01  1.57827153e+01 -7.91523753e+00]
#  [-6.44679867e+00  3.16480110e+01  1.92662516e+01  7.25127685e+00]
#  [-1.04537195e+01  2.35893548e+01  1.38108322e+01  7.54842639e-01]
#  [-1.54245366e+01 -7.35230228e+00  2.01594123e+00 -3.88430080e-01]
#  [-9.06952393e+00  2.19818880e+01  3.00963498e+00 -5.09719011e+00]
#  [ 1.40724459e+01  1.62711222e+01  3.88363842e+00 -5.50849538e+00]
#  [ 6.45263770e+00  1.85559673e+01 -1.25236851e+01  6.95998857e+00]
#  [ 1.82486176e+00  3.15481081e+01  1.43134796e+01  3.57272182e+00]
#  [-2.62332378e+01  1.54252751e+00  1.66796803e+01  5.58187223e+00]
#  [ 3.06049472e+01  3.78561287e+01 -1.40529458e+01 -3.48436711e-01]
#  [ 1.19992520e+00  1.15123134e+00  4.79655176e+00 -6.87578705e+00]
#  [ 6.92262902e+00  4.96853295e+01  1.68129567e+01  1.19080281e-01]
#  [-5.56078020e+00  1.16890619e+01  1.05829721e+01 -1.03829012e+01]
#  [-2.29356015e+01  5.39777674e+00 -8.32724915e-01  1.44938853e+00]
#  [-1.77366695e+01  1.11618049e+00 -1.60015440e+01 -3.63857207e+00]
#  [-1.88156171e+01 -4.47915911e+00 -1.35009518e+01 -4.13807566e+00]
#  [ 4.44976029e+01  5.03542481e+01 -1.18022788e+01  5.66216721e+01]
#  [ 3.75297770e+00 -4.57365225e+00 -1.31697772e+00  7.69408685e+00]
#  [-1.59422396e+01  1.79779321e+00 -2.41447580e+01  9.08023895e+00]
#  [-9.20570687e+00  2.67553505e+00 -2.34715427e+01 -1.75764966e+00]
#  [ 4.98272352e+00  3.38165279e+00 -2.01883807e+01 -5.92815280e+00]
#  [-1.67558201e+01 -1.33177712e+01 -1.87547529e+01 -2.51812914e-02]
#  [-8.30553086e+00 -1.01194559e+01 -1.11415483e+01  1.21514278e+00]
#  [ 1.81034087e+01  1.84056479e+01 -1.85871591e+01 -1.29689144e+01]
#  [-7.67514170e+00 -1.11299978e+00 -1.17389491e+01 -4.31391706e+00]
#  [ 1.69060338e+01  2.80474402e+01 -2.63875181e+01 -1.21005474e+01]
#  [-3.89535933e+01 -6.55614569e+00 -2.81346194e+01  9.88204329e-01]
#  [ 2.60666502e+00  1.53623610e+01 -1.79066339e+01 -1.01356802e+01]
#  [-6.93686444e+00 -2.30690450e+01 -2.44437343e+01  2.16995901e+00]
#  [ 1.43409178e+01 -1.58231435e+01 -1.18537821e+01 -7.00411089e+00]
#  [-1.42269246e+01 -1.08624016e+01 -2.06166752e+01  3.50151508e+00]
#  [-6.57468260e+00 -1.42403890e+01  1.85098884e+01  6.17480393e+00]
#  [-2.94931465e+01 -9.81898111e-01  9.07676672e+00  1.85036631e+01]
#  [-1.01782737e+01 -8.85271783e+00  1.07413059e+01  9.83175829e+00]
#  [-1.25511487e+01  4.94620767e-02  2.40392102e+01 -6.85630765e+00]
#  [-1.21034734e+01 -2.67171971e-01  1.33569579e+01  4.52087889e+00]
#  [-3.96765490e+00 -1.98681592e+01 -6.49727248e+00  3.06412133e+00]
#  [-1.60048237e+01 -1.09744941e+01  4.89109884e+00 -4.30981917e+00]
#  [-1.43633092e+01 -1.35571800e+01 -4.35008258e+00  8.58221309e-01]
#  [-1.58673312e+01 -8.93790997e+00  1.92323445e+01  4.39809378e+00]
#  [ 1.57504795e+01 -5.45891853e+00 -8.73021502e+00  1.06686620e+00]
#  [-2.73645287e+01 -5.50444282e+00  5.37704766e+00  1.50686731e+01]
#  [-8.67892931e+00 -1.68278423e+01  8.93251676e+00  2.56526727e-01]
#  [-7.11866233e+00 -1.15705299e+01 -1.24920728e+00 -2.44111183e+00]
#  [ 4.71262812e+00 -1.33931043e+01  1.53019483e+01 -8.61435580e+00]
#  [-2.08556614e+01 -9.44349770e+00  9.24083819e-01  2.24700182e+00]
#  [-6.61726969e+00 -1.47086085e+01 -4.72717618e+00  3.85307467e+00]
#  [-1.93652408e+01 -4.70531706e+00  9.79939127e+00  7.00060993e-01]
#  [ 2.19360122e+00 -1.70177010e+01  1.95527942e+01 -1.37302002e+01]
#  [-1.99141326e+01 -1.12205272e+01  1.17995601e+01 -4.04204682e+00]
#  [ 9.57264072e+00 -9.31476702e+00  2.26343238e+01 -2.01119217e+01]
#  [-7.60908060e+00 -1.79349704e+01  8.93882828e+00 -9.44706422e+00]
#  [ 2.47096801e+00 -1.27780004e+01 -1.22238626e+01 -8.69369520e+00]
#  [-1.50094818e+01 -7.35903340e+00  1.29517820e+01 -1.05666327e+01]
#  [-7.84724348e+00 -1.14013042e+01  1.69398873e+01  2.96794038e+00]
#  [ 3.17399972e-01  1.17936505e+01 -1.35502789e+00 -9.58548417e+00]
#  [ 4.12668516e+00  4.04970807e+00  1.72391958e+01  2.13931176e+01]
#  [ 1.08660224e+02 -3.71811924e+01  4.10294091e+00 -9.43020727e+00]
#  [ 9.83341996e+00  2.09000557e+01  1.55246114e+01  5.24569288e+00]
#  [-1.93527337e+01  2.97579971e+00 -3.78860421e+00  2.00505210e+01]
#  [ 1.54212869e+01  4.54988593e+00 -2.14473690e+01  1.38069853e+01]
#  [ 1.17162662e+01  1.81164412e+01  8.57180176e+00 -1.39982987e+01]
#  [ 1.61734449e+01 -1.40044311e+01 -3.94375212e+00  2.77775828e+01]
#  [-3.38337630e+00 -3.42061914e+00  2.07025102e+01  3.92982530e+01]
#  [-6.32120251e+00  4.19667133e+00 -9.51181157e+00  6.38352834e+00]
#  [-1.49177782e+01 -2.69115255e+00  7.41726499e+00  4.58970948e+00]
#  [ 1.24143526e+02 -1.23855828e+01  5.62618735e+00  1.38602131e+01]
#  [ 8.32692970e+01 -4.56737814e+01  4.26489157e+01  2.59106189e+01]
#  [ 3.27911379e+01 -2.18533942e+01  1.21259397e+01 -6.20451429e+00]
#  [ 3.16572858e+01 -5.07700660e+00  2.83244206e+01 -8.36559645e+00]
#  [ 1.24741732e+01 -2.87516318e+00 -2.11908739e+01  4.52521204e+00]
#  [-1.22629975e+00  9.55925641e+00  5.41378176e+00  6.38572327e+00]
#  [ 3.69028349e+01 -1.44713137e+00  1.58156727e+01 -1.87585699e+01]
#  [ 3.71210513e+01 -6.68084684e+00  7.07154135e+00 -1.19451911e+01]
#  [-1.12622296e+01  3.63144692e+01 -3.66906925e+00  4.66133327e+00]
#  [-6.72395065e+00 -7.48617116e+00  1.56018887e+01  9.81282226e+00]
#  [-4.78312719e+00 -6.38703049e+00  1.95710248e+01  1.25672447e+01]
#  [ 2.96471237e+01  1.89619655e+01 -1.04250099e+01  2.87973772e+01]
#  [ 5.23871393e+00 -1.74134698e+01 -6.30864660e+00  4.51641981e+00]
#  [-3.06336014e+00  4.11535362e+00 -1.96434718e+01  7.13841589e+00]
#  [-1.15643812e+01 -8.24154643e+00 -9.00591653e+00  4.78199351e+00]
#  [ 1.09369328e+01  1.36447605e+01 -1.01097638e+01  4.71384443e+00]
#  [-7.96316761e+00  2.87730300e+00 -1.81156088e+01  4.35937871e+00]
#  [ 1.35998722e+00  7.23795745e+00 -2.68850745e+00 -3.95188156e+00]
#  [ 3.73331044e+01 -7.82010760e+00 -9.68294133e+00 -1.01972033e+01]
#  [-1.09161870e+01  5.10696895e+00  8.65896208e+00  2.85705342e+00]
#  [-1.24721551e+01 -4.89118025e-01  8.57517492e+00 -3.39059441e+00]
#  [ 2.23819510e+01 -2.50835775e+01 -1.01645692e+00 -1.13968741e+01]
#  [ 5.68733365e+01 -9.37818796e+00 -6.66438415e+00 -1.07725311e+01]
#  [ 4.50459856e+01  4.35008685e+01 -3.48125849e+00 -2.13505665e+01]
#  [ 3.56089786e+00  2.90006168e+01  3.49513664e+00 -7.35840023e+00]
#  [-7.41839553e+00 -1.47281575e+01 -2.15145452e+00 -5.84362161e+00]
#  [ 1.51621483e+01  2.74550889e+01 -1.36974468e+01 -1.03917055e+01]
#  [-1.56500906e+01  4.52869231e-01 -1.81866587e+01 -1.08152301e+01]
#  [ 6.82703420e+01  2.53013414e+01 -2.61172650e+01 -2.46716136e+01]]
#
# [0.45401201 0.20383815 0.16403083 0.09094239]

# %%
import random
fig = plt.figure(figsize=(18,12))
ax = fig.add_subplot(111, projection='3d')
color = ['yellow','black','aqua','green','teal','orange','navy','pink','purple','red']
for x in range(0,115):
    ax.scatter(newX[x,0],newX[x,1],newX[x,2],color=color[random.randint(0,9)])
# Out:
# C:\Users\CqC33\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
