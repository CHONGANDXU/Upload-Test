# %% [markdown]
# ## 实验项目名称：基于朴素贝叶斯的垃圾短信过滤
#
# ## 实验目的和要求：
# * 掌握常见的数据读取方式
# * 掌握pandas常用属性与方法
# * 掌握朴素朴素贝叶斯模型的构建
# * 掌握训练集和测试集的划分
# * 了解模型评估的方法
# * 了解文本分词的方法
# * 了解文本可视化的方法
#
#
# ## 实验内容：
# #### 首先提取并转化短信中的文本信息，然后用朴素贝叶斯算法对短信进行分类，实现过滤垃圾短信。
#
# 贝叶斯模型使用方法参考：https://scikit-learn.org/stable/modules/classes.html#module-sklearn.naive_bayes

# %% [markdown]
# ## 实验步骤及结果：

# %% [markdown]
# #### 1.数据介绍
# 该数据集是包含短信的文本信息，带有表明该短信是否为垃圾短信的标签。垃圾短信标记为spam，而非垃圾短信标记为ham。
# 以下是一些关于垃圾短信和非垃圾短信的例子。
#
# 如标记为spam（垃圾短信）：
#
# England v Macedonia - dont miss the goals/team news. Txt ur national team to 87077 eg ENGLAND to 87077 Try:WALES, SCOTLAND 4txt/煤1.20 POBOXox36504W45WQ 16+07732584351 - Rodger Burns - MSG = We tried to call you re your reply to our sms for a free nokia mobile + free camcorder.
#
# Please call now 08000930705 for delivery tomorrow07732584351 - Rodger Burns - MSG = We tried to call you re your reply to our sms for a free nokia mobile + free camcorder. Please call now 08000930705 for delivery tomorrow
#
# 标记为ham（非垃圾短信）：
#
# I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.
#
# #### 2.数据读取及数据探索
# 首先使用 Pandas 库中的read_csv()函数导入sms_spam.csv文件数据。注意读文件编码：encoding='ISO-8859-1'

# %%
import pandas as pd
sms_row=pd.read_csv("python_data/sms_spam.csv",encoding="ISO-8859-1")
print(sms_row)
# Out:
#       type                                               text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5569  spam  This is the 2nd time we have tried 2 contact u...
# 5570   ham              Will Ã¼ b going to esplanade fr home?
# 5571   ham  Pity, * was in mood for that. So...any other s...
# 5572   ham  The guy did some bitching but I acted like i'd...
# 5573   ham                         Rofl. Its true to its name
#
# [5574 rows x 2 columns]

# %% [markdown]
# 使用sms_rowFrame中的descirbe()方法，查看数据情况

# %%
sms_row.describe()
# Out:
#         type                    text
# count   5574                    5574
# unique     2                    5160
# top      ham  Sorry, I'll call later
# freq    4827                      30

# %% [markdown]
# 查看数据大小（即有多少样本，几个特征）

# %%
sms_row.shape
# Out:
# (5574, 2)

# %% [markdown]
# 查看数据类型

# %%
sms_row.dtypes
# Out:
# type    object
# text    object
# dtype: object

# %% [markdown]
# 当前的特征变量type是一个字符串向量。它是一个分类变量，所以将其转换成一个数值变量将有利于后续的数据处理，用1表示垃圾短信，0表示非垃圾短信

# %%
sms_row.astype({'type' : 'str'})
list=[]
for i in sms_row.iloc[:,0]:   
    if i=="ham":list.append(0)
    if i=="spam":i=list.append(1)
new_type=pd.DataFrame(list,columns=['new_type'])
sms_new=pd.concat([sms_row,new_type], axis=1)
sms_new.head()
# Out:
#    type                                               text  new_type
# 0   ham  Go until jurong point, crazy.. Available only ...         0
# 1   ham                      Ok lar... Joking wif u oni...         0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3   ham  U dun say so early hor... U c already then say...         0
# 4   ham  Nah I don't think he goes to usf, he lives aro...         0

# %% [markdown]
# 观察特征变量type的分布情况，查看垃圾短信和非垃圾短信分别有多少条

# %%
count=sms_new['new_type'].value_counts(1)
print(count*5574)
# Out:
# 0    4827.0
# 1     747.0
# Name: new_type, dtype: float64

# %% [markdown]
# #### 3 数据准备——处理和分析文本数据
# 短信就是由词、空格、数字和标点符号组成的文本字符串。处理这种类型的复杂数据需要大量的思考和工作，一方面需要考虑如何去除数字和标点符号，如何处理没有意义的单词，如and、but和or等，以及如何将句子分解成单个的单词。幸运的是，Python 的 sklearn 库中已经包含了这些功能。
#
# 处理文本数据的第一步涉及到创建一个语料库，即一个文本文件的集合。在这个例子中，一个文本文件就是指一条短信，通过下面的命令建立一个包含训练数据中短信的语料库。

# %%
import string
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud

# %% [markdown]
# #### 3.1 数据预处理
# ##### 分割单词
# 统计一个文件或一个字符串中所有单词出现的次数。由于句子中存在标点符号，直接对字符串切割的话会把单词和标点切割在一起。
# 语料库现在包含5574条短信的原始文本内容。在将文本内容分解成单词之前，我们需要进行一些清理步骤以去除标点符号和可能会影响结果的其他字符。例如，我们将把单词hello!、HELLO和Hello等都作为单词hello的样本。
#
# 首先我们利用translate方法+string.punctuation去除文本内容中的标点符号和数字，并将文本中所有的字符串都转换成小写形式：

# %%
def tolower(text):
    return text.lower()

def removePunctuation(text):
    trantab = text.maketrans({key: None for key in string.punctuation+('123456789')})#生成映射表
    return text.translate(trantab)
#处理字符串中的标点符号及数字，如果出现标点和数字就替换为None

sms_new['text']=sms_new['text'].map(removePunctuation).map(tolower)
sms_new
# Out:
#       type                                               text  new_type
# 0      ham  go until jurong point crazy available only in ...         0
# 1      ham                            ok lar joking wif u oni         0
# 2     spam  free entry in  a wkly comp to win fa cup final...         1
# 3      ham        u dun say so early hor u c already then say         0
# 4      ham  nah i dont think he goes to usf he lives aroun...         0
# ...    ...                                                ...       ...
# 5569  spam  this is the nd time we have tried  contact u u...         1
# 5570   ham               will ã¼ b going to esplanade fr home         0
# 5571   ham  pity  was in mood for that soany other suggest...         0
# 5572   ham  the guy did some bitching but i acted like id ...         0
# 5573   ham                          rofl its true to its name         0
#
# [5574 rows x 3 columns]

# %% [markdown]
# 在分析文本数据时，一个常见的做法就是去除填充词，比如to、and、but和or，这些词称为停用词（stop word）。我们将使用sklearn包中的 CountVectorizer 方法来去除停止词并计算文本的词频分布情况。
#
# CountVectorizer是属于常见的特征数值计算类，是一个文本特征提取方法。对于每一个训练文本，它只考虑每种词汇在该训练文本中出现的频率。
#
# CountVectorizer会将文本中的词语转换为词频矩阵，它通过fit_transform函数计算各个词语出现的次数。
# stop_words	设置停用词，设为english将使用内置的英语停用词，设为一个list可自定义停用词，设为None不使用停用词，设为None且max_df∈[0.7, 1.0)将自动根据当前的语料库建立停用词表。
#
# decode_error：默认为strict，遇到不能解码的字符将报UnicodeDecodeError错误，设为ignore将会忽略解码错误，还可以设为replace

# %%
count_vect = CountVectorizer(stop_words="english",decode_error='ignore')
sms_counts = count_vect.fit_transform(sms_new['text'])
#print(sms_counts)
count_vect.vocabulary_#返回词汇表
# Out:
# {'jurong': 3765,
#  'point': 5480,
#  'crazy': 1609,
#  'available': 553,
#  'bugis': 1002,
#  'great': 2972,
#  'world': 8197,
#  'la': 3920,
#  'buffet': 1000,
#  'cine': 1331,
#  'got': 2933,
#  'amore': 326,
#  'wat': 7962,
#  'ok': 5047,
#  'lar': 3956,
#  'joking': 3733,
#  'wif': 8090,
#  'oni': 5078,
#  'free': 2666,
#  'entry': 2263,
#  'wkly': 8148,
#  'comp': 1445,
#  'win': 8104,
#  'fa': 2393,
#  'cup': 1665,
#  'final': 2516,
#  'tkts': 7405,
#  'st': 6817,
#  '00': 0,
#  'text': 7244,
#  'receive': 5878,
#  'questionstd': 5770,
#  'txt': 7612,
#  'ratetcs': 5823,
#  'apply': 407,
#  '000overs': 14,
#  'dun': 2124,
#  'say': 6234,
#  'early': 2143,
#  'hor': 3307,
#  'nah': 4750,
#  'dont': 2031,
#  'think': 7318,
#  'goes': 2889,
#  'usf': 7763,
#  'lives': 4121,
#  'freemsg': 2674,
#  'hey': 3204,
#  'darling': 1729,
#  'weeks': 8019,
#  'word': 8183,
#  'id': 3426,
#  'like': 4071,
#  'fun': 2739,
#  'tb': 7172,
#  'xxx': 8324,
#  'std': 6863,
#  'chgs': 1276,
#  'send': 6325,
#  'rcv': 5834,
#  'brother': 967,
#  'speak': 6732,
#  'treat': 7539,
#  'aids': 254,
#  'patent': 5275,
#  'request': 5990,
#  'melle': 4441,
#  'oru': 5143,
#  'minnaminunginte': 4525,
#  'nurungu': 4976,
#  'vettam': 7830,
#  'set': 6354,
#  'callertune': 1073,
#  'callers': 1072,
#  'press': 5609,
#  'copy': 1550,
#  'friends': 2699,
#  'winner': 8117,
#  'valued': 7800,
#  'network': 4823,
#  'customer': 1678,
#  'selected': 6311,
#  'receivea': 5879,
#  'prize': 5643,
#  'reward': 6049,
#  'claim': 1337,
#  '000': 1,
#  'code': 1396,
#  'kl': 3880,
#  'valid': 7796,
#  'hours': 3326,
#  'mobile': 4584,
#  'months': 4629,
#  'entitled': 2260,
#  'update': 7720,
#  'latest': 3972,
#  'colour': 1419,
#  'mobiles': 4585,
#  'camera': 1097,
#  '00000': 3,
#  'im': 3455,
#  'gonna': 2906,
#  'home': 3273,
#  'soon': 6682,
#  'want': 7941,
#  'talk': 7138,
#  'stuff': 6961,
#  'anymore': 377,
#  'tonight': 7463,
#  'ive': 3645,
#  'cried': 1626,
#  'today': 7422,
#  'chances': 1213,
#  'cash': 1156,
#  '0000': 2,
#  'pounds': 5546,
#  'csh': 1643,
#  'cost': 1563,
#  '0pday': 57,
#  'days': 1756,
#  'tsandcs': 7574,
#  'reply': 5982,
#  'hl': 3240,
#  'info': 3515,
#  'urgent': 7742,
#  'won': 8167,
#  'week': 8014,
#  'membership': 4447,
#  'jackpot': 3655,
#  'tc': 7174,
#  'wwwdbuknet': 8271,
#  'lccltd': 3992,
#  'pobox': 5462,
#  '0ldnwarw': 48,
#  'searching': 6282,
#  'right': 6061,
#  'words': 8186,
#  'thank': 7262,
#  'breather': 935,
#  'promise': 5682,
#  'wont': 8174,
#  'help': 3174,
#  'granted': 2961,
#  'fulfil': 2736,
#  'wonderful': 8171,
#  'blessing': 816,
#  'times': 7380,
#  'date': 1738,
#  'sunday': 7028,
#  'xxxmobilemovieclub': 8325,
#  'use': 7757,
#  'credit': 1616,
#  'click': 1359,
#  'wap': 7946,
#  'link': 4094,
#  'message': 4472,
#  'httpwap': 3355,
#  'xxxmobilemovieclubcomnqjkgighjjgcbl': 8326,
#  'oh': 5040,
#  'kim': 3847,
#  'watching': 7967,
#  'eh': 2191,
#  'remember': 5949,
#  'spell': 6748,
#  'yes': 8365,
#  'did': 1903,
#  'naughty': 4779,
#  'make': 4315,
#  'wet': 8055,
#  'fine': 2523,
#  'thats': 7276,
#  'way': 7980,
#  'feel': 2470,
#  'gota': 2934,
#  'england': 2243,
#  'macedonia': 4279,
#  'miss': 4544,
#  'goalsteam': 2880,
#  'news': 4836,
#  'ur': 7739,
#  'national': 4772,
#  'team': 7190,
#  'trywales': 7572,
#  'scotland': 6261,
#  'txtãº0': 7623,
#  'poboxox0wwq': 5469,
#  'seriously': 6347,
#  'iâ': 3650,
#  'going': 2894,
#  'try': 7569,
#  'ha': 3046,
#  'ã¼': 8451,
#  'pay': 5288,
#  'da': 1694,
#  'stock': 6891,
#  'comin': 1435,
#  'aft': 219,
#  'finish': 2529,
#  'lunch': 4253,
#  'str': 6918,
#  'lor': 4178,
#  'ard': 433,
#  'smth': 6626,
#  'ffffffffff': 2488,
#  'alright': 306,
#  'meet': 4426,
#  'sooner': 6684,
#  'just': 3767,
#  'forced': 2618,
#  'eat': 2156,
#  'slice': 6575,
#  'really': 5858,
#  'hungry': 3382,
#  'tho': 7335,
#  'sucks': 6999,
#  'mark': 4350,
#  'getting': 2835,
#  'worried': 8203,
#  'knows': 3892,
#  'sick': 6486,
#  'turn': 7596,
#  'pizza': 5411,
#  'lol': 4155,
#  'convincing': 1536,
#  'catch': 1168,
#  'bus': 1022,
#  'frying': 2724,
#  'egg': 2186,
#  'tea': 7184,
#  'eating': 2159,
#  'moms': 4608,
#  'left': 4014,
#  'dinner': 1936,
#  'love': 4204,
#  'amp': 327,
#  'packing': 5199,
#  'car': 1122,
#  'ill': 3451,
#  'let': 4038,
#  'know': 3887,
#  'theres': 7302,
#  'room': 6107,
#  'ahhh': 245,
#  'work': 8189,
#  'vaguely': 7791,
#  'does': 2000,
#  'wait': 7912,
#  'clear': 1353,
#  'sure': 7056,
#  'sarcastic': 6208,
#  'doesnt': 2002,
#  'live': 4117,
#  'yeah': 8352,
#  'apologetic': 394,
#  'fallen': 2420,
#  'actin': 156,
#  'spoilt': 6776,
#  'child': 1292,
#  'caught': 1172,
#  'till': 7374,
#  'doing': 2014,
#  'badly': 605,
#  'cheers': 1258,
#  'tell': 7209,
#  'fear': 2462,
#  'fainting': 2410,
#  'housework': 3331,
#  'quick': 5771,
#  'cuppa': 1667,
#  'thanks': 7263,
#  'subscription': 6988,
#  'ringtone': 6070,
#  'uk': 7645,
#  'charged': 1225,
#  'month': 4625,
#  'confirm': 1491,
#  'replying': 5984,
#  'yup': 8432,
#  'look': 4166,
#  'timings': 7387,
#  'msg': 4677,
#  'xuhui': 8320,
#  'learn': 4004,
#  'nd': 4785,
#  'lesson': 4036,
#  'oops': 5095,
#  'roommates': 6110,
#  'letter': 4040,
#  'decide': 1793,
#  'hello': 3167,
#  'hows': 3337,
#  'saturday': 6224,
#  'texting': 7251,
#  'youd': 8395,
#  'decided': 1794,
#  'tomo': 7448,
#  'trying': 7571,
#  'invite': 3578,
#  'pls': 5447,
#  'ahead': 243,
#  'watts': 7977,
#  'wanted': 7943,
#  'weekend': 8016,
#  'abiola': 109,
#  'forget': 2624,
#  'need': 4798,
#  'crave': 1606,
#  'sweet': 7086,
#  'arabian': 430,
#  'steed': 6870,
#  'mmmmmm': 4574,
#  'yummy': 8427,
#  'rodger': 6096,
#  'burns': 1019,
#  'tried': 7548,
#  'sms': 6620,
#  'nokia': 4898,
#  'camcorder': 1095,
#  '000000': 4,
#  'delivery': 1832,
#  'tomorrow': 7451,
#  'seeing': 6300,
#  'hope': 3297,
#  'man': 4325,
#  'endowed': 2233,
#  'ltgt': 4238,
#  'inches': 3484,
#  'callsmessagesmissed': 1090,
#  'calls': 1088,
#  'didnt': 1905,
#  'hep': 3186,
#  'immunisation': 3467,
#  'nigeria': 4853,
#  'fair': 2411,
#  'hopefully': 3301,
#  'tyler': 7624,
#  'maybe': 4399,
#  'ask': 484,
#  'bit': 791,
#  'stubborn': 6949,
#  'hospital': 3314,
#  'kept': 3818,
#  'telling': 7210,
#  'weak': 7987,
#  'sucker': 6997,
#  'hospitals': 3315,
#  'suckers': 6998,
#  'thinked': 7319,
#  'time': 7376,
#  'saw': 6233,
#  'class': 1345,
#  'gram': 2953,
#  'usually': 7774,
#  'runs': 6153,
#  'half': 3063,
#  'eighth': 2193,
#  'smarter': 6598,
#  'gets': 2831,
#  'second': 6286,
#  'fyi': 2754,
#  'ride': 6060,
#  'morning': 4638,
#  'hes': 3199,
#  'crashing': 1605,
#  'place': 5413,
#  'wow': 8221,
#  'realized': 5856,
#  'embarassed': 2214,
#  'accomodations': 137,
#  'thought': 7339,
#  'liked': 4072,
#  'best': 748,
#  'happy': 3098,
#  'cave': 1176,
#  'sorry': 6694,
#  'offered': 5020,
#  'embarassing': 2215,
#  'ac': 123,
#  'sptv': 6799,
#  'new': 4831,
#  'jersey': 3699,
#  'devils': 1883,
#  'detroit': 1877,
#  'red': 5902,
#  'wings': 8115,
#  'play': 5429,
#  'ice': 3421,
#  'hockey': 3257,
#  'correct': 1555,
#  'incorrect': 3495,
#  'end': 2228,
#  'mallika': 4324,
#  'sherawat': 6407,
#  'yesterday': 8376,
#  'lturlgt': 4242,
#  'congrats': 1498,
#  'year': 8354,
#  'special': 6734,
#  'cinema': 1332,
#  'pass': 5263,
#  'suprman': 7054,
#  'matrix': 4385,
#  'starwars': 6849,
#  'bx0ipwe': 1044,
#  '0pm': 60,
#  'later': 3970,
#  'meeting': 4429,
#  'reached': 5840,
#  'yesgauti': 8369,
#  'sehwag': 6308,
#  'odi': 5013,
#  'series': 6346,
#  'pick': 5381,
#  'burger': 1014,
#  'pain': 5206,
#  'killing': 3844,
#  'good': 2908,
#  'joke': 3728,
#  'girls': 2856,
#  'situation': 6537,
#  'seekers': 6301,
#  'checking': 1252,
#  'iq': 3592,
#  'took': 7470,
#  'forever': 2621,
#  'come': 1427,
#  'double': 2047,
#  'check': 1248,
#  'hair': 3058,
#  'dresser': 2082,
#  'said': 6175,
#  'wun': 8257,
#  'cut': 1682,
#  'short': 6448,
#  'nice': 4846,
#  'pleased': 5440,
#  'advise': 201,
#  'following': 2599,
#  'recent': 5882,
#  'review': 6047,
#  'mob': 4582,
#  'awarded': 572,
#  'bonus': 859,
#  'song': 6676,
#  'dedicated': 1804,
#  'day': 1751,
#  'dedicate': 1803,
#  'valuable': 7798,
#  'frnds': 2709,
#  'rply': 6127,
#  'complimentary': 1464,
#  'trip': 7549,
#  'eurodisinc': 2302,
#  'trav': 7531,
#  'acoentry': 152,
#  'dis': 1949,
#  '0morefrmmob': 51,
#  'shracomorsglsuplt0': 6471,
#  'ls': 4229,
#  'aj': 265,
#  'hear': 3142,
#  'divorce': 1978,
#  'barbie': 638,
#  'comes': 1431,
#  'kens': 3816,
#  'plane': 5420,
#  'wah': 7905,
#  'lucky': 4246,
#  'save': 6229,
#  'money': 4613,
#  'hee': 3158,
#  'finished': 2531,
#  'hi': 3209,
#  'babe': 588,
#  'wanna': 7939,
#  'xx': 8321,
#  'kkwhere': 3877,
#  'youhow': 8398,
#  'performed': 5325,
#  'waiting': 7916,
#  'machan': 4281,
#  'cool': 1542,
#  'gentleman': 2818,
#  'dignity': 1926,
#  'respect': 6011,
#  'peoples': 5318,
#  'shy': 6481,
#  'pa': 5194,
#  'operate': 5102,
#  'looking': 4170,
#  'job': 3714,
#  'tas': 7156,
#  'earn': 2144,
#  'ah': 241,
#  'stop': 6901,
#  'urgnt': 7746,
#  'real': 5850,
#  'yo': 8386,
#  'tickets': 7365,
#  'jacket': 3654,
#  'used': 7758,
#  'multis': 4707,
#  'started': 6842,
#  'requests': 5991,
#  'came': 1096,
#  'bed': 705,
#  'coins': 1403,
#  'factory': 2401,
#  'gotta': 2939,
#  'nitros': 4878,
#  'ela': 2197,
#  'kanoil': 3792,
#  'download': 2055,
#  'wen': 8038,
#  'donâ': 2037,
#  'stand': 6830,
#  'close': 1366,
#  'youâ': 8418,
#  'll': 4125,
#  'night': 4855,
#  'spent': 6753,
#  'late': 3965,
#  'afternoon': 221,
#  'casualty': 1166,
#  'means': 4413,
#  'havent': 3122,
#  'stuffmoro': 6965,
#  'includes': 3488,
#  'sheets': 6402,
#  'smile': 6607,
#  'pleasure': 5442,
#  'trouble': 7555,
#  'pours': 5548,
#  'rain': 5795,
#  'sum': 7019,
#  'hurts': 3397,
#  'becoz': 703,
#  'loves': 4214,
#  'smiling': 6611,
#  'service': 6350,
#  'representative': 5988,
#  '0ampm': 35,
#  'guaranteed': 3014,
#  'planning': 5425,
#  'buy': 1033,
#  'lido': 4053,
#  'collected': 1412,
#  'simply': 6509,
#  'password': 5271,
#  'mix': 4564,
#  'verify': 7826,
#  'usher': 7765,
#  'britney': 957,
#  'fml': 2589,
#  'po': 5461,
#  'box': 894,
#  'mk': 4567,
#  '0ppw': 75,
#  'telugu': 7215,
#  'moviewat': 4664,
#  'abt': 118,
#  'loads': 4132,
#  'loans': 4134,
#  'wk': 8144,
#  'hols': 3271,
#  'run': 6150,
#  'forgot': 2629,
#  'hairdressers': 3060,
#  'appointment': 410,
#  'shower': 6464,
#  'cause': 1173,
#  'prob': 5649,
#  'coffee': 1398,
#  'animation': 350,
#  'okay': 5048,
#  'price': 5622,
#  'long': 4162,
#  'legal': 4017,
#  'ave': 559,
#  'ams': 332,
#  'gone': 2903,
#  'driving': 2091,
#  'test': 7238,
#  'youre': 8408,
#  'mean': 4409,
#  'guess': 3022,
#  'gave': 2787,
#  'boston': 881,
#  'men': 4452,
#  'changed': 1215,
#  'search': 6281,
#  'location': 4137,
#  'nyc': 4986,
#  'cuz': 1689,
#  'signin': 6497,
#  'page': 5202,
#  'says': 6239,
#  'umma': 7654,
#  'life': 4056,
#  'vava': 7812,
#  'lot': 4188,
#  'dear': 1775,
#  'wishes': 8130,
#  'birthday': 789,
#  'making': 4319,
#  'truly': 7563,
#  'memorable': 4449,
#  'aight': 256,
#  'hit': 3231,
#  'ip': 3586,
#  'address': 175,
#  'considering': 1509,
#  'computer': 1471,
#  'isnt': 3611,
#  'minecraft': 4518,
#  'server': 6349,
#  'grumpy': 3005,
#  'old': 5065,
#  'people': 5317,
#  'mom': 4605,
#  'better': 755,
#  'lying': 4269,
#  'jokes': 3730,
#  'worry': 8206,
#  'busy': 1027,
#  'plural': 5452,
#  'noun': 4939,
#  'research': 5997,
#  'dinnermsg': 1937,
#  'cos': 1561,
#  'things': 7317,
#  'scared': 6246,
#  'mah': 4302,
#  'loud': 4199,
#  'gent': 2816,
#  'contact': 1514,
#  'weekends': 8017,
#  'draw': 2069,
#  'shows': 6470,
#  'hrs': 3346,
#  '0ppm': 71,
#  'wa': 7901,
#  'openin': 5099,
#  'sentence': 6338,
#  'formal': 2632,
#  'juz': 3772,
#  'tt': 7581,
#  'eatin': 2158,
#  'puttin': 5748,
#  'weighthaha': 8024,
#  'anythin': 381,
#  'happened': 3090,
#  'entered': 2253,
#  'cabin': 1050,
#  'bday': 690,
#  'boss': 880,
#  'felt': 2480,
#  'askd': 485,
#  'invited': 3579,
#  'apartment': 388,
#  'went': 8041,
#  'specially': 6739,
#  'holiday': 3267,
#  'flights': 2566,
#  'operator': 5103,
#  '000pmin': 16,
#  'goodo': 2922,
#  'friday': 2692,
#  'eggpotato': 2187,
#  'ratio': 5824,
#  'tortilla': 7488,
#  'needed': 4800,
#  'hmmmy': 3253,
#  'uncle': 7662,
#  'informed': 3519,
#  'paying': 5294,
#  'school': 6252,
#  'directly': 1943,
#  'food': 2607,
#  'private': 5640,
#  'account': 141,
#  'statement': 6852,
#  'unredeemed': 7705,
#  'points': 5481,
#  'identifier': 3433,
#  'expires': 2371,
#  'caller': 1071,
#  'landline': 3943,
#  'boxwrc': 902,
#  'applespairsall': 405,
#  'malarky': 4321,
#  'todays': 7428,
#  'voda': 7879,
#  'numbers': 4972,
#  'ending': 2230,
#  'award': 571,
#  'match': 4373,
#  'quoting': 5783,
#  'standard': 6831,
#  'rates': 5822,
#  'app': 398,
#  'sao': 6202,
#  'mu': 4696,
#  'predict': 5583,
#  'ã¼ll': 8452,
#  'buying': 1036,
#  'knowyetunde': 3895,
#  'sent': 6336,
#  'bother': 883,
#  'sending': 6328,
#  'involve': 3583,
#  'shouldnt': 6457,
#  'imposed': 3473,
#  'apologise': 395,
#  'girl': 2852,
#  'del': 1822,
#  'bak': 614,
#  'lucyxx': 4250,
#  'kkhow': 3871,
#  'tmorrowpls': 7410,
#  'accomodate': 136,
#  'answer': 365,
#  'question': 5767,
#  'sunshine': 7035,
#  'quiz': 5778,
#  'sony': 6679,
#  'dvd': 2133,
#  'player': 5431,
#  'country': 1578,
#  'algarve': 285,
#  'ansr': 364,
#  'sptyrone': 6800,
#  'laid': 3934,
#  'dogging': 2008,
#  'locations': 4138,
#  'direct': 1942,
#  'join': 3723,
#  'uks': 7648,
#  'largest': 3960,
#  'bt': 984,
#  'txting': 7618,
#  'gravel': 2966,
#  'nt': 4960,
#  'eca': 2161,
#  'pmsg0p': 5459,
#  'haf': 3052,
#  'msn': 4689,
#  'yijuehotmailcom': 8383,
#  'rooms': 6111,
#  'befor': 719,
#  'activities': 162,
#  'youll': 8402,
#  'msgs': 4681,
#  'chat': 1237,
#  'svc': 7072,
#  'hardcore': 3100,
#  'services': 6351,
#  'age': 228,
#  'yr': 8422,
#  'lazy': 3990,
#  'type': 7626,
#  'lect': 4011,
#  'pouch': 5543,
#  'sir': 6523,
#  'mail': 4306,
#  'swt': 7101,
#  'nver': 4981,
#  'tired': 7391,
#  'little': 4116,
#  'lovable': 4203,
#  'persons': 5342,
#  'cozsomtimes': 1592,
#  'occupy': 5005,
#  'biggest': 771,
#  'hearts': 3150,
#  'gud': 3016,
#  'ni': 4844,
#  'open': 5096,
#  'ya': 8336,
#  'dot': 2046,
#  'whats': 8061,
#  'staff': 6821,
#  'taking': 7135,
#  'replied': 5980,
#  'randy': 5815,
#  'sexy': 6366,
#  'female': 2481,
#  'local': 4136,
#  'luv': 4259,
#  'netcollex': 4819,
#  '00000p': 6,
#  'ummmawill': 7655,
#  'inour': 3536,
#  'begin': 724,
#  'qatar': 5754,
#  'pray': 5576,
#  'hard': 3099,
#  'ki': 3832,
#  'deleted': 1826,
#  'sindu': 6513,
#  'birla': 785,
#  'soft': 6648,
#  'wine': 8113,
#  'flowing': 2580,
#  'nevering': 4828,
#  'thk': 7327,
#  'plaza': 5438,
#  'typical': 7629,
#  'dirt': 1946,
#  'floor': 2574,
#  'windows': 8110,
#  'shirt': 6422,
#  'mouth': 4659,
#  'dream': 2073,
#  'chores': 1318,
#  'joy': 3745,
#  'lots': 4191,
#  'tv': 7601,
#  'exist': 2354,
#  'hail': 3057,
#  'mist': 4555,
#  'aaooooright': 98,
#  'leaving': 4010,
#  'house': 3327,
#  'interview': 3565,
#  'boy': 903,
#  'meare': 4415,
#  'missing': 4548,
#  'annoncement': 356,
#  'years': 8355,
#  'arrange': 460,
#  'safe': 6170,
#  'envy': 2267,
#  'sees': 6305,
#  'parentsi': 5242,
#  'hand': 3072,
#  'excited': 2342,
#  'spend': 6751,
#  'bootydelious': 872,
#  'inviting': 3580,
#  'friend': 2697,
#  'wwwsmsacubootydelious': 8291,
#  'frnd': 2708,
#  'bangbabes': 628,
#  'order': 5127,
#  'content': 1518,
#  'goto': 2938,
#  'bangb': 627,
#  'internetservice': 3564,
#  'menu': 4460,
#  'cultures': 1661,
#  'module': 4598,
#  'avoid': 565,
#  'missunderstding': 4553,
#  'wit': 8135,
#  'beloved': 739,
#  'ones': 5076,
#  'escape': 2286,
#  'fancy': 2432,
#  'bridge': 941,
#  'needs': 4804,
#  'lager': 3933,
#  'completely': 1460,
#  'formclark': 2636,
#  'utter': 7776,
#  'waste': 7959,
#  'axis': 579,
#  'bank': 630,
#  'hmmm': 3247,
#  'hop': 3296,
#  'muz': 4732,
#  'discuss': 1962,
#  'liao': 4045,
#  'coming': 1436,
#  'bloody': 831,
#  'hell': 3165,
#  'believe': 730,
#  'surname': 7062,
#  'mr': 4669,
#  'clue': 1379,
#  'spanish': 6726,
#  'begins': 725,
#  'bath': 661,
#  'goodfine': 2912,
#  'youve': 8415,
#  'carlos': 1143,
#  'mall': 4323,
#  'turns': 7599,
#  'staying': 6860,
#  'til': 7373,
#  'smoke': 6614,
#  'worth': 8212,
#  'log': 4144,
#  'spoke': 6777,
#  'maneesha': 4335,
#  'wed': 8004,
#  'satisfied': 6217,
#  'experience': 2365,
#  'toll': 7443,
#  'lifted': 4065,
#  'hopes': 3303,
#  'offer': 5019,
#  'especially': 2289,
#  'approaches': 414,
#  'studying': 6959,
#  'anyways': 385,
#  'gr': 2948,
#  'trust': 7565,
#  'guys': 3038,
#  'greatbye': 2974,
#  'handsome': 3078,
#  'finding': 2521,
#  'working': 8193,
#  'net': 4818,
#  'mummy': 4711,
#  'wheres': 8073,
#  'boytoy': 908,
#  'haha': 3053,
#  'awesome': 574,
#  'minute': 4533,
#  'freephone': 2678,
#  'ampm': 329,
#  'xmas': 8316,
#  'radio': 5788,
#  'jus': 3766,
#  'bathe': 662,
#  'sis': 6528,
#  'using': 7766,
#  'finishes': 2532,
#  'unique': 7690,
#  '0th': 86,
#  'august': 538,
#  'wwwareyouuniquecouk': 8262,
#  'joined': 3724,
#  'league': 4002,
#  'touch': 7497,
#  'deal': 1768,
#  'personal': 5337,
#  'finally': 2518,
#  'completed': 1459,
#  'course': 1584,
#  'suggest': 7012,
#  'stays': 6861,
#  'able': 111,
#  'ors': 5140,
#  'stool': 6900,
#  'settled': 6358,
#  'wishin': 8131,
#  'mrng': 4671,
#  'hav': 3117,
#  'story': 6917,
#  'hamster': 3071,
#  'dead': 1766,
#  'tmr': 7411,
#  'pm': 5456,
#  'orchard': 5126,
#  'mrt': 4673,
#  'kate': 3798,
#  'evening': 2310,
#  'babyjontet': 596,
#  'enc': 2227,
#  'bucks': 993,
#  'darlin': 1728,
#  'college': 1416,
#  'refilled': 5914,
#  'successfully': 6996,
#  'inr': 3539,
#  'ltdecimalgt': 4234,
#  'keralacircle': 3820,
#  'prepaid': 5594,
#  'balance': 617,
#  'rs': 6130,
#  'transaction': 7520,
#  'kr': 3908,
#  'goodmorning': 2916,
#  'sleeping': 6567,
#  'ga': 2755,
#  'alter': 311,
#  'dat': 1736,
#  'ericsson': 2273,
#  'oso': 5146,
#  'oredi': 5130,
#  'dats': 1744,
#  'straight': 6919,
#  'dogg': 2006,
#  'connection': 1502,
#  'refund': 5919,
#  'shoot': 6439,
#  'big': 769,
#  'ready': 5848,
#  'bruv': 979,
#  'break': 927,
#  'rewarding': 6050,
#  'semester': 6321,
#  'kkgoodstudy': 3870,
#  'noe': 4888,
#  'leh': 4020,
#  'sounds': 6710,
#  'heading': 3133,
#  'prediction': 5586,
#  ...}

# %% [markdown]
# 由于原始的词频矩阵中维度过高，所以我们考虑利用TF-IDF进行特征提取，设定最小词频数为5，共提取出 1489 个变量。

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vect = TfidfVectorizer(stop_words="english",decode_error='ignore',min_df=5)
sms_tfidf = tfidf_vect.fit_transform(sms_new['text'])
print(sms_tfidf)
# Out:
#   (0, 1392)	0.24957440209745532
#   (0, 505)	0.20520670087532522
#   (0, 220)	0.36977694791468796
#   (0, 662)	0.3588431134526403
#   (0, 1451)	0.3018497639522368
#   (0, 509)	0.24362782863457974
#   (0, 157)	0.36977694791468796
#   (0, 87)	0.33284280367971714
#   (0, 273)	0.3389756857538296
#   (0, 958)	0.34235627475788927
#   (1, 1421)	0.5150086246115386
#   (1, 640)	0.6248349687001974
#   (1, 668)	0.4872048371517248
#   (1, 882)	0.32707617632765007
#   (2, 63)	0.255158847512287
#   (2, 1321)	0.19076417867891038
#   (2, 1016)	0.25270945096907044
#   (2, 1248)	0.18643200729558965
#   (2, 0)	0.16570337756281314
#   (2, 1181)	0.23786188212796605
#   (2, 431)	0.2781402102909373
#   (2, 280)	0.30089158501706936
#   (2, 1425)	0.22385530616502997
#   (2, 241)	0.29726949876804276
#   (2, 1435)	0.28798053890167397
#   :	:
#   (5569, 367)	0.29079411207276706
#   (5569, 789)	0.3129803738784916
#   (5569, 253)	0.25452360207125974
#   (5569, 1275)	0.2047625364922822
#   (5569, 1306)	0.30638298855832286
#   (5569, 844)	0.287932360273848
#   (5569, 1440)	0.25122124552375236
#   (5569, 1)	0.20500154686543542
#   (5569, 222)	0.23293977530628127
#   (5569, 979)	0.2446793622062732
#   (5570, 452)	0.649916122039853
#   (5570, 1500)	0.4718033643821884
#   (5570, 498)	0.4198889841066188
#   (5570, 564)	0.4227337941260889
#   (5571, 815)	1.0
#   (5572, 517)	0.3565548143376243
#   (5572, 613)	0.4173047956235527
#   (5572, 162)	0.41079174521830025
#   (5572, 478)	0.3996952545639501
#   (5572, 316)	0.2713728002869773
#   (5572, 1405)	0.276005024849767
#   (5572, 696)	0.23206509576701267
#   (5572, 594)	0.33569156920778837
#   (5572, 453)	0.23206509576701267
#   (5573, 1309)	1.0

# %% [markdown]
# #### 3.2 建立训练数据集和测试数据集
# 由于已经为分析准备好了数据，所以现在我们需要将数据分成训练数据集和测试数据集，从而可以把垃圾短信分类器应用到之前没有学习过的数据上，并据此对分类器的性能进行评估。

# %%
from sklearn.model_selection import train_test_split
sms_train_x,sms_test_x,sms_train_y,sms_test_y=train_test_split(sms_tfidf,sms_new['new_type'],test_size=0.2, random_state=None)
print("训练数据集的x大小为 ",sms_train_x.shape)
print("训练数据集的y大小为 ",sms_train_y.shape)
print("测试数据集的x大小为 ",sms_test_x.shape)
print("测试数据集的y大小为 ",sms_train_y.shape)
# Out:
# 训练数据集的x大小为  (4459, 1501)
# 训练数据集的y大小为  (4459,)
# 测试数据集的x大小为  (1115, 1501)
# 测试数据集的y大小为  (4459,)

# %% [markdown]
# #### 3.3 可视化文本数据——词云
# 词云是一种可视化地描绘单词出现在文本数据中频率的方式。词云是由随机分布在词云图中的单词构成的，经常出现在文本中的单词会以较大的字体呈现，而不太常见的单词将会以较小的字体呈现。最近，这种类型的图已经变得越来越流行，因为它提供了一种观察社交媒体网站上热门话题的方式。
#
# WordCloud包提供了一个简单的函数来创建这种类型的图形，我们将应用这个函数使短信中单词类型可视化。比较垃圾短信和非垃圾短信的词云将有助于我们了解朴素贝叶斯短信过滤器是否有可能成功

# %%
wc = WordCloud()
wc.generate(''.join(sms_new['text']))
plt.imshow(wc)
plt.show()

# %%
wc.generate(''.join(sms_new['text'][sms_new['new_type']==1]))
plt.imshow(wc)
plt.show()

# %%
wc.generate(''.join(sms_new['text'][sms_new['new_type']==0]))
plt.imshow(wc)
plt.show()

# %% [markdown]
# ### 4 训练及测试模型
# 因为我们已经将原始短信转换成了可以用一个统计模型代表的形式，所以此时是应用朴素贝叶斯算法的时候了。该算法将根据单词的存在与否来统计一条给定的短信是否是垃圾短信的概率。
#
# 我们采用sklearn包中的朴素贝叶斯算法实现。

# %%
import numpy as np
from sklearn.naive_bayes import MultinomialNB


clf = MultinomialNB()
clf.fit(sms_train_x,sms_train_y)

predicted = pd.DataFrame(clf.predict(sms_test_x),columns=["predict"])
test_row = pd.DataFrame(sms_test_y)
wrong_answer=0
for i in range(0,1115):
    if(predicted.iloc[i,0]!=test_row.iloc[i,0]):
        wrong_answer=wrong_answer+1

print("预测的错误率为 ",wrong_answer/1115)
# Out:
# 预测的错误率为  0.023318385650224215

# %% [markdown]
# ## 实验结果分析:

# %% [markdown]
# 1.垃圾短信和非垃圾短信的各有多少？

# %% [markdown]
# 2.训练集和测试集是如何划分的？

# %% [markdown]
# 3.在你划分的测试集上，模型评分是多少？

# %% [markdown]
# ## 实验所需软件环境和库：
# Jupyter Notebook、Python、Sklearn、Numpy、Pandas、WordCloud

# %% [markdown]
# ## 教师评语:
